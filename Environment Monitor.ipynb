# %% [markdown]
# Import Pyserial Package (docs: https://pyserial.readthedocs.io/en/latest/)

# %%
import serial
from pathlib import Path
import time

# %% [markdown]
# # Configuration
# Function which allows user to configure:
# - Serial Comm Port Selection
# - Number of Sensors Connected
# - Device Label (lab name etc.) - will determine the path of the output file.

# %%
def config():
    
    invalid_chars = ['<','>', ':', '/', "\\",'?', "*"]
    
    # User inputs the Arduino Comm Port
    while True:
        try:
            n_port = int(input("\nSelect Comm Port: "))
            port = f'COM{abs(n_port)}'
            print(f"'{port}' selected.")
            break
        except ValueError:
            print("\nError... Comm Port Input must be an integer. Please Re-Input Below:")
    
    # User inputs the number of sensors
    while True:
        try:
            n_sensors = int(input("\nNumber of Enviroment Sensors: "))
            break
        except ValueError:
            print("\nError... Input must be an integer. Please Re-Input Below:")
    
    # User inputs label for device
    while True:
        tag = input("\nMonitor Name: ")
        if any(char in tag for char in invalid_chars):
            print(f"Error... Must not contain illegal characters:")
            print(" ".join(invalid_chars))
            print("Please Re-Input Below:")
        else:
            break
            
    while True: 
        query = input("\nConfirm? (Y/N): ")
        if query == "Y" or query == "y":
            break
        elif query == "N" or query == "n":
            [port, n_sensors, tag] = config()
            return [port, n_sensors, tag]
            
    # Could add another input of where to save data???
    
    # Writes user-inputs to a .txt and returns a list of the user-inputs
    config_file = open('config/config.txt', 'w')  # write new CSV if file doesn't exist
    config_file.write(f"Config Params: Serial Port, Number of Enviorment Sensors, Device Label\n{port}\n{n_sensors}\n{tag}")
    config_file.close()
    print(f"\nConfig File Written to '{path_config}' succesfully.")
    return [port, n_sensors, tag]

# %% [markdown]
# # Monitor Function
# Function that uses the pyserial lib to communicate with the Arduino.
# Checks if device is reset and updates value labels for use in the sketch.
#
# Reads each line of the serial monitor which corresponds to a timetamp, label, value and units (for each sensor) respectively
#
# For example, a device which has 3 sensors and a timestamp associated to an onboard RTC will output 10 lines. (3 * n_sensors + 1):
#
# Note: Sensor names (_relhumid, _temp, _press) are already defined in the arduino sketch.

# %%
def write_headers(ser, path, n_sensors):
    data_list = []
    for i in range(3*3 + 1 + 1):  # 3 sensors connected (hard coded for now), 3 columns, first line is time and
        # read arduino serial comms, decode from ASCII to python default 'utf'and strip formatting characters
        ser_line = ser.readline().decode('utf').strip("\r\n")
        data_list.append(ser_line)  # append the comms to a list
        
    if not Path(path).exists():
        print(f"\nWriting New File to '{path}'")
        file = open(path, 'w')  # write new CSV if file doesn't exist
    else:
        print(f"\nWriting New Headers to '{path}'")
        file = open(path, 'r+')  # else append the first line
        
    print("\nAdalogger Time :", data_list[0])

    headers = ['Time Stamp']
    for i in range(n_sensors):
        headers.append(data_list[3*i+1] + " ("  + data_list[3*i+3] + ")")
        print(data_list[i*3+1], ":", data_list[i*3+2], 
              data_list[i*3+3])

    headers = ','.join(headers)
    file.write("%s\n" % headers)  
    # first line written is the headers if new file created
    
    file.close()
    file = open(path, 'a+')
    csv_list = [data_list[0]]
    for i in range(n_sensors):
        csv_list.append(data_list[i*3+2])
    csv_line = ','.join(csv_list)    
    file.write(str(csv_line))  # write data to a CSV
    file.write("\n")
    ser.close()
    return file

# %%
def temp_humid_monitor(port, baud_rate, path, n_sensors, tag):
    try:
        # Define the serial object
        ser = serial.Serial(port, baud_rate)
        
        # Close and Reopen the Serial Port
        ser.close()
        ser.open()   
        print("\n\nRunning...\n")
        tag = f'{tag}\n'  # sketch reads the written data up till the newline character.
        
        # Check if file already exists
        # If not, write new file and read comms to find tag names and create headers.
        if not Path(path).exists():
            ser.write(bytes(tag, 'ASCII')) # write the label to the arduino to start printing data
            file = write_headers(ser, path, n_sensors)

        else:
            file = open(path, 'a+')  # otherwise append to existing CSV
        
        ser.close()
        ser.open()
        # Start Monitoring Loop
        while True:
            # in the case of updated tags while device running, need to re-write the tags each loop itt
            ser.write(bytes(tag, 'ASCII')) 
            data_list = []
            for i in range((3*3 + 1 + 1)):
                # read arduino serial, decode and strip any formatting characters
                ser_line = ser.readline().decode('utf').strip("\r\n")
                data_list.append(ser_line)
            print("\nAdalogger Time : ", data_list[0])  # first index is the time step
            csv_list = [data_list[0]]
            for i in range(n_sensors):
                print(data_list[i*3+1], ":", data_list[i*3+2], 
                      data_list[i*3+3])
                csv_list.append(data_list[i*3+2])
            csv_line = ','.join(csv_list)

            file.write(str(csv_line))  # write data to a CSV
            file.write("\n")
            file.close()  # closes file
            file = open(path, 'a+')
            ser.close()
            ser.open()
            time.sleep(0.5)
    
    # Close port if script interrupted
    except KeyboardInterrupt:
        file.close()
        ser.close()
        raise KeyboardInterrupt

# %% [markdown]
# # Main Script
# The main program which executes the respective functions in order.

# %%
baud_rate = 9600  # pre-defined baud rate
path_config = 'config/config.txt'  # path to save the config file

# User-input to determine wether to re-configure the device or re-load previous data.
while True:
    query = input("Configure Device? (Y/N): ")
    if query == "Y" or query == "y":
        [port, n_sensors, tag] = config()
        break
        
    elif query == "N" or query == "n":
        if not Path(path_config).exists():
            print("Previous config. not found. Running setup:")
            [port, n_sensors, tag] = config()
            n_sensors = int(n_sensors)
        else:
            config_file = open(path_config, 'r')
            config_data = config_file.readlines()
            config_file.close()
            [port, n_sensors, tag] = [config_data[i].strip("\n") for i in range(1,len(config_data))]
            n_sensors = int(n_sensors)
            print(f'\nPrevious Config Found...\nPort: {port}\nNumber of Enviroment Sensors: {n_sensors}\nLabel: {tag}')
            while True:
                query = input("\nIs this correct? (Y/N): ")
                if query == "Y" or query == "y":
                    break
                elif query == "N" or query == "n":
                    [port, n_sensors, tag] = config()
                    break
        break

path = f"data/{tag}_data.csv"  # can allow user to define the path to save data. Hard coded for now.

while True:
    try: 
        temp_humid_monitor(port, baud_rate, path, n_sensors, tag)
    except KeyboardInterrupt:
        while True:
            query = input("\nInterrupted. Re-Configure? (Y/N): ")
            if query == "Y" or query == "y":
                n_sensors_old = n_sensors
                tag_old = tag
                [port, n_sensors, tag] = config()
                path = f"data/{tag}_data.csv"  # can allow user to define the path to save data. Hard coded for now.
                if n_sensors > n_sensors_old and tag == tag_old:
                    ser = serial.Serial(port, baud_rate) 
                    tag = f'{tag}\n'  # sketch reads the written data up till the newline character.
                    ser.write(bytes(tag, 'ASCII')) # write the label to the arduino to start printing data
                    ser = write_headers(ser, path, n_sensors)
                    ser.close()
                break
            elif query == "N" or query == "n":
                print(f'\nPrevious Config Found...\nPort: {port}\nNumber of Enviroment Sensors: {n_sensors}\nLabel: {tag}')
                while True:
                    query = input("\nIs this correct? (Y/N): ")
                    if query == "Y" or query == "y":
                        break
                    elif query == "N" or query == "n":
                        [port, n_sensors, tag] = config()
                        break
                break
# Out:
# Configure Device? (Y/N):  y
#
# Select Comm Port:  4
# 'COM4' selected.
# Number of Enviroment Sensors:  3
#
# Monitor Name:  lab_3
#
# Confirm? (Y/N):  y
# Config File Written to 'config/config.txt' succesfully.
#
#
# Running...
#
#
# Writing New File to 'data/lab_3_data.csv'
#
# Adalogger Time : 2021/6/28 12:3:41
# lab_3_relhumid : 44.31 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.36 Pa
#
# Adalogger Time :  2021/6/28 12:3:43
# lab_3_relhumid : 44.33 %
# lab_3_temp : 24.04 degC
# lab_3_press : 101137.61 Pa
#
# Adalogger Time :  2021/6/28 12:3:45
# lab_3_relhumid : 44.43 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101137.66 Pa
#
# Adalogger Time :  2021/6/28 12:3:47
# lab_3_relhumid : 44.61 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.25 Pa
#
# Adalogger Time :  2021/6/28 12:3:49
# lab_3_relhumid : 44.50 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.08 Pa
#
# Adalogger Time :  2021/6/28 12:3:51
# lab_3_relhumid : 44.41 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.30 Pa
#
# Adalogger Time :  2021/6/28 12:3:53
# lab_3_relhumid : 44.33 %
# lab_3_temp : 24.06 degC
# lab_3_press : 101138.42 Pa
#
# Adalogger Time :  2021/6/28 12:3:55
# lab_3_relhumid : 44.28 %
# lab_3_temp : 24.04 degC
# lab_3_press : 101138.42 Pa
#
# Adalogger Time :  2021/6/28 12:3:57
# lab_3_relhumid : 44.21 %
# lab_3_temp : 24.04 degC
# lab_3_press : 101138.35 Pa
#
# Adalogger Time :  2021/6/28 12:3:58
# lab_3_relhumid : 44.16 %
# lab_3_temp : 24.04 degC
# lab_3_press : 101138.48 Pa
#
# Adalogger Time :  2021/6/28 12:4:0
# lab_3_relhumid : 44.18 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101138.15 Pa
#
# Adalogger Time :  2021/6/28 12:4:2
# lab_3_relhumid : 44.16 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.16 Pa
#
# Adalogger Time :  2021/6/28 12:4:4
# lab_3_relhumid : 44.18 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.20 Pa
#
# Adalogger Time :  2021/6/28 12:4:6
# lab_3_relhumid : 44.18 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.25 Pa
#
# Adalogger Time :  2021/6/28 12:4:8
# lab_3_relhumid : 44.18 %
# lab_3_temp : 24.05 degC
# lab_3_press : 101138.34 Pa
#
# Adalogger Time :  2021/6/28 12:4:10
# lab_3_relhumid : 44.18 %
# lab_3_press : 101125.00 Pa
#
# Adalogger Time :  2021/6/28 12:17:5
# lab_3_relhumid : 45.23 %
# lab_3_temp : 23.83 degC
# lab_3_press : 101125.13 Pa
#
# Adalogger Time :  2021/6/28 12:17:7
# lab_3_relhumid : 45.23 %
# lab_3_temp : 23.84 degC
# lab_3_press : 101125.16 Pa
#
# Adalogger Time :  2021/6/28 12:17:9
# lab_3_relhumid : 45.23 %
# lab_3_temp : 23.84 degC
# lab_3_press : 101125.15 Pa
#
# Adalogger Time :  2021/6/28 12:17:11
# lab_3_relhumid : 45.23 %
# lab_3_temp : 23.84 degC
# lab_3_press : 101125.25 Pa
#
# ...
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.49 Pa
#
# Adalogger Time :  2021/6/28 12:53:51
# lab_3_relhumid : 45.08 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.39 Pa
#
# Adalogger Time :  2021/6/28 12:53:53
# lab_3_relhumid : 45.05 %
# lab_3_temp : 24.04 degC
# lab_3_press : 101081.06 Pa
#
# Adalogger Time :  2021/6/28 12:53:55
# lab_3_relhumid : 45.05 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.15 Pa
#
# Adalogger Time :  2021/6/28 12:53:57
# lab_3_relhumid : 45.05 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.07 Pa
#
# Adalogger Time :  2021/6/28 12:53:58
# lab_3_relhumid : 45.08 %
# lab_3_temp : 24.04 degC
# lab_3_press : 101081.14 Pa
#
# Adalogger Time :  2021/6/28 12:54:0
# lab_3_relhumid : 45.08 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.04 Pa
#
# Adalogger Time :  2021/6/28 12:54:2
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.04 degC
# lab_3_press : 101080.57 Pa
#
# Adalogger Time :  2021/6/28 12:54:4
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.91 Pa
#
# Adalogger Time :  2021/6/28 12:54:6
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.98 Pa
#
# Adalogger Time :  2021/6/28 12:54:8
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.09 Pa
#
# Adalogger Time :  2021/6/28 12:54:10
# lab_3_relhumid : 45.08 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.05 Pa
#
# Adalogger Time :  2021/6/28 12:54:12
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.72 Pa
#
# Adalogger Time :  2021/6/28 12:54:14
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.84 Pa
#
# Adalogger Time :  2021/6/28 12:54:16
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.04 Pa
#
# Adalogger Time :  2021/6/28 12:54:18
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.09 Pa
#
# Adalogger Time :  2021/6/28 12:54:20
# lab_3_relhumid : 45.08 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.20 Pa
#
# Adalogger Time :  2021/6/28 12:54:22
# lab_3_relhumid : 45.08 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.18 Pa
#
# Adalogger Time :  2021/6/28 12:54:24
# lab_3_relhumid : 45.08 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.23 Pa
#
# Adalogger Time :  2021/6/28 12:54:25
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.23 Pa
#
# Adalogger Time :  2021/6/28 12:54:27
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.25 Pa
#
# Adalogger Time :  2021/6/28 12:54:29
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101081.30 Pa
#
# Adalogger Time :  2021/6/28 12:54:31
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101081.14 Pa
#
# Adalogger Time :  2021/6/28 12:54:33
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101081.09 Pa
#
# Adalogger Time :  2021/6/28 12:54:35
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101081.27 Pa
#
# Adalogger Time :  2021/6/28 12:54:37
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.99 Pa
#
# Adalogger Time :  2021/6/28 12:54:39
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101081.12 Pa
#
# Adalogger Time :  2021/6/28 12:54:41
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101081.09 Pa
#
# Adalogger Time :  2021/6/28 12:54:43
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101081.09 Pa
#
# Adalogger Time :  2021/6/28 12:54:45
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101081.13 Pa
#
# Adalogger Time :  2021/6/28 12:54:47
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.60 Pa
#
# Adalogger Time :  2021/6/28 12:54:49
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.31 Pa
#
# Adalogger Time :  2021/6/28 12:54:51
# lab_3_relhumid : 45.21 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.73 Pa
#
# Adalogger Time :  2021/6/28 12:54:52
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.78 Pa
#
# Adalogger Time :  2021/6/28 12:54:54
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.73 Pa
#
# Adalogger Time :  2021/6/28 12:54:56
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.90 Pa
#
# Adalogger Time :  2021/6/28 12:54:58
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.95 Pa
#
# Adalogger Time :  2021/6/28 12:55:0
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.98 Pa
#
# Adalogger Time :  2021/6/28 12:55:2
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.79 Pa
#
# Adalogger Time :  2021/6/28 12:55:4
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101081.09 Pa
#
# Adalogger Time :  2021/6/28 12:55:6
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.02 degC
# lab_3_press : 
%
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.67 Pa
#
# Adalogger Time :  2021/6/28 12:55:54
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.85 Pa
#
# Adalogger Time :  2021/6/28 12:55:56
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.74 Pa
#
# Adalogger Time :  2021/6/28 12:55:58
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.25 Pa
#
# Adalogger Time :  2021/6/28 12:56:0
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.62 Pa
#
# Adalogger Time :  2021/6/28 12:56:2
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.57 Pa
#
# Adalogger Time :  2021/6/28 12:56:4
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101079.68 Pa
#
# Adalogger Time :  2021/6/28 12:56:6
# lab_3_relhumid : 45.28 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.52 Pa
#
# Adalogger Time :  2021/6/28 12:56:8
# lab_3_relhumid : 45.25 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.59 Pa
#
# Adalogger Time :  2021/6/28 12:56:10
# lab_3_relhumid : 45.25 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.66 Pa
#
# Adalogger Time :  2021/6/28 12:56:11
# lab_3_relhumid : 45.23 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.65 Pa
#
# Adalogger Time :  2021/6/28 12:56:13
# lab_3_relhumid : 45.21 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.58 Pa
#
# Adalogger Time :  2021/6/28 12:56:15
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.72 Pa
#
# Adalogger Time :  2021/6/28 12:56:17
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.43 Pa
#
# Adalogger Time :  2021/6/28 12:56:19
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.45 Pa
#
# Adalogger Time :  2021/6/28 12:56:21
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.52 Pa
#
# Adalogger Time :  2021/6/28 12:56:23
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.41 Pa
#
# Adalogger Time :  2021/6/28 12:56:25
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.61 Pa
#
# Adalogger Time :  2021/6/28 12:56:27
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.57 Pa
#
# Adalogger Time :  2021/6/28 12:56:29
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.34 Pa
#
# Adalogger Time :  2021/6/28 12:56:31
# lab_3_relhumid : 45.10 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.45 Pa
#
# Adalogger Time :  2021/6/28 12:56:33
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.42 Pa
#
# Adalogger Time :  2021/6/28 12:56:35
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.57 Pa
#
# Adalogger Time :  2021/6/28 12:56:36
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.45 Pa
#
# Adalogger Time :  2021/6/28 12:56:38
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.43 Pa
#
# Adalogger Time :  2021/6/28 12:56:40
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.48 Pa
#
# Adalogger Time :  2021/6/28 12:56:42
# lab_3_relhumid : 45.13 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.52 Pa
#
# Adalogger Time :  2021/6/28 12:56:44
# lab_3_relhumid : 45.21 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.40 Pa
#
# Adalogger Time :  2021/6/28 12:56:46
# lab_3_relhumid : 45.25 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.22 Pa
#
# Adalogger Time :  2021/6/28 12:56:48
# lab_3_relhumid : 45.25 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.31 Pa
#
# Adalogger Time :  2021/6/28 12:56:50
# lab_3_relhumid : 45.21 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101079.63 Pa
#
# Adalogger Time :  2021/6/28 12:56:52
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101079.95 Pa
#
# Adalogger Time :  2021/6/28 12:56:54
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.76 Pa
#
# Adalogger Time :  2021/6/28 12:56:56
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.03 Pa
#
# Adalogger Time :  2021/6/28 12:56:58
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.10 Pa
#
# Adalogger Time :  2021/6/28 12:57:0
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.12 Pa
#
# Adalogger Time :  2021/6/28 12:57:2
# lab_3_relhumid : 45.16 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.19 Pa
#
# Adalogger Time :  2021/6/28 12:57:3
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.12 Pa
#
# Adalogger Time :  2021/6/28 12:57:5
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.19 Pa
#
# Adalogger Time :  2021/6/28 12:57:7
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.01 degC
# lab_3_press : 101080.16 Pa
#
# Adalogger Time :  2021/6/28 12:57:9
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.13 Pa
#
# Adalogger Time :  2021/6/28 12:57:11
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.16 Pa
#
# Adalogger Time :  2021/6/28 12:57:13
# lab_3_relhumid : 45.21 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.05 Pa
#
# Adalogger Time :  2021/6/28 12:57:15
# lab_3_relhumid : 45.21 %
# lab_3_temp : 24.03 degC
# lab_3_press : 101080.34 Pa
#
# Adalogger Time :  2021/6/28 12:57:17
# lab_3_relhumid : 45.21 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101080.13 Pa
#
# Adalogger Time :  2021/6/28 12:57:19
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.48 Pa
#
# Adalogger Time :  2021/6/28 12:57:21
# lab_3_relhumid : 45.18 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.22 Pa
#
# Adalogger Time :  2021/6/28 12:57:23
# lab_3_relhumid : 45.28 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.47 Pa
#
# Adalogger Time :  2021/6/28 12:57:25
# lab_3_relhumid : 45.40 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.60 Pa
#
# Adalogger Time :  2021/6/28 12:57:27
# lab_3_relhumid : 45.40 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.58 Pa
#
# Adalogger Time :  2021/6/28 12:57:29
# lab_3_relhumid : 45.33 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.63 Pa
#
# Adalogger Time :  2021/6/28 12:57:30
# lab_3_relhumid : 45.25 %
# lab_3_temp : 24.02 degC
# lab_3_press : 101079.59 Pa
#
# Adalogger Time :  2021/6/28 12:57:32
# lab_3_relhumid : 45.23 %
# lab_3_temp : 24.02 degC
# lab_3_press : 